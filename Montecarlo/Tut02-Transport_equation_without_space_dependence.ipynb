# %%
import numpy as np
import matplotlib.pyplot as plt  # library for plots

# %%
# exponential law
sigma_s=0.5
sigma_a=0.7
t=2.3
Nt=np.random.poisson(t)
Ti=np.random.exponential(1/sigma_s, Nt)
Ui1=np.random.uniform(0,2*np.pi, Nt)
Ui2=np.random.uniform(0,np.pi, Nt)
# variable in the sphere (i.e. merge Ui1 and Ui2)





N = 10000
NN = np.arange(1,N)
LL = []
MM = []
for n in NN:
  L = np.random.exponential(1/alpha, N)
  M = np.random.exponential(1/beta, N)
  M = M * (alpha / beta) * np.exp((beta-alpha)*M)
  LL.append(np.mean(L))
  MM.append(np.mean(M))
p1=plt.plot(NN,LL,label='monte 1')
p2=plt.plot(NN,MM, label='monte 2')

plt.legend()

# %%
# Out:
# 0.3369809158723907
# 0.3276726536691844

# %%
beta =
